# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

print(pd.__version__)
# Out:
# 0.25.1

# %% [markdown]
# ## Crear un DataFrame vacío:

# %%
pd.DataFrame(data=[None], index=[None], columns=[None])
# Out:
#       NaN
# NaN  None

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Crear un DataFrame marvel_df con los siguientes datos:

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
marvel_df = pd.DataFrame(data=marvel_data)

# %%
marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %% [markdown]
# ## Agregar los nombres de columna:

# %%
marvel_df.columns = ['Nombre','Género','Año']

# %%
marvel_df
# Out:
#               Nombre  Género   Año
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %% [markdown]
# ## Agregue nombres de índice al marvel_df (use el 'nombre' como índice)

# %%
marvel_df.index = marvel_df['Nombre']
marvel_df
# Out:
#                             Nombre  Género   Año
# Nombre
# Spider-Man              Spider-Man    male  1962
# Captain America    Captain America    male  1941
# Wolverine                Wolverine    male  1974
# Iron Man                  Iron Man    male  1963
# Thor                          Thor    male  1963
# Thing                        Thing    male  1961
# Mister Fantastic  Mister Fantastic    male  1961
# Hulk                          Hulk    male  1962
# Beast                        Beast    male  1963
# Invisible Woman    Invisible Woman  female  1961
# Storm                        Storm  female  1975
# Namor                        Namor    male  1939
# Hawkeye                    Hawkeye    male  1964
# Daredevil                Daredevil    male  1964
# Doctor Strange      Doctor Strange    male  1963
# Hank Pym                  Hank Pym    male  1962
# Scarlet Witch        Scarlet Witch  female  1964
# Wasp                          Wasp  female  1963
# ...

# %% [markdown]
# ## Eliminar la colmuna Nombre, porque ahora corrsponde al índice:

# %%
marvel_df.drop(columns=['Nombre'])
# Out:
#                   Género   Año
# Nombre
# Spider-Man          male  1962
# Captain America     male  1941
# Wolverine           male  1974
# Iron Man            male  1963
# Thor                male  1963
# Thing               male  1961
# Mister Fantastic    male  1961
# Hulk                male  1962
# Beast               male  1963
# Invisible Woman   female  1961
# Storm             female  1975
# Namor               male  1939
# Hawkeye             male  1964
# Daredevil           male  1964
# Doctor Strange      male  1963
# Hank Pym            male  1962
# Scarlet Witch     female  1964
# Wasp              female  1963
# Black Widow       female  1964
# Vision              male  1968

# %%
marvel_df.drop(['Nombre'], axis=1)
# Out:
#                   Género   Año
# Nombre
# Spider-Man          male  1962
# Captain America     male  1941
# Wolverine           male  1974
# Iron Man            male  1963
# Thor                male  1963
# Thing               male  1961
# Mister Fantastic    male  1961
# Hulk                male  1962
# Beast               male  1963
# Invisible Woman   female  1961
# Storm             female  1975
# Namor               male  1939
# Hawkeye             male  1964
# Daredevil           male  1964
# Doctor Strange      male  1963
# Hank Pym            male  1962
# Scarlet Witch     female  1964
# Wasp              female  1963
# Black Widow       female  1964
# Vision              male  1968

# %%
marvel_df
# Out:
#                             Nombre  Género   Año
# Nombre
# Spider-Man              Spider-Man    male  1962
# Captain America    Captain America    male  1941
# Wolverine                Wolverine    male  1974
# Iron Man                  Iron Man    male  1963
# Thor                          Thor    male  1963
# Thing                        Thing    male  1961
# Mister Fantastic  Mister Fantastic    male  1961
# Hulk                          Hulk    male  1962
# Beast                        Beast    male  1963
# Invisible Woman    Invisible Woman  female  1961
# Storm                        Storm  female  1975
# Namor                        Namor    male  1939
# Hawkeye                    Hawkeye    male  1964
# Daredevil                Daredevil    male  1964
# Doctor Strange      Doctor Strange    male  1963
# Hank Pym                  Hank Pym    male  1962
# Scarlet Witch        Scarlet Witch  female  1964
# Wasp                          Wasp  female  1963
# ...

# %%
# Para hacer borrado físico se actualiza el DataFrame sobre alguno de Los códigos anteriores:
marvel_df = marvel_df.drop(['Nombre'], axis=1)
marvel_df
# Out:
#                   Género   Año
# Nombre
# Spider-Man          male  1962
# Captain America     male  1941
# Wolverine           male  1974
# Iron Man            male  1963
# Thor                male  1963
# Thing               male  1961
# Mister Fantastic    male  1961
# Hulk                male  1962
# Beast               male  1963
# Invisible Woman   female  1961
# Storm             female  1975
# Namor               male  1939
# Hawkeye             male  1964
# Daredevil           male  1964
# Doctor Strange      male  1963
# Hank Pym            male  1962
# Scarlet Witch     female  1964
# Wasp              female  1963
# Black Widow       female  1964
# Vision              male  1968

# %% [markdown]
# ## Eliminar las filas 'Namor' y 'Hank Pym':

# %%
marvel_df.drop(['Namor','Hank Pym'],axis=0)
# Out:
#                   Género   Año
# Nombre
# Spider-Man          male  1962
# Captain America     male  1941
# Wolverine           male  1974
# Iron Man            male  1963
# Thor                male  1963
# Thing               male  1961
# Mister Fantastic    male  1961
# Hulk                male  1962
# Beast               male  1963
# Invisible Woman   female  1961
# Storm             female  1975
# Hawkeye             male  1964
# Daredevil           male  1964
# Doctor Strange      male  1963
# Scarlet Witch     female  1964
# Wasp              female  1963
# Black Widow       female  1964
# Vision              male  1968

# %%
# Para borrar asignamos el cambio:

marvel_df = marvel_df.drop(['Namor','Hank Pym'], axis=0)
marvel_df
# Out:
#                   Género   Año
# Nombre
# Spider-Man          male  1962
# Captain America     male  1941
# Wolverine           male  1974
# Iron Man            male  1963
# Thor                male  1963
# Thing               male  1961
# Mister Fantastic    male  1961
# Hulk                male  1962
# Beast               male  1963
# Invisible Woman   female  1961
# Storm             female  1975
# Hawkeye             male  1964
# Daredevil           male  1964
# Doctor Strange      male  1963
# Scarlet Witch     female  1964
# Wasp              female  1963
# Black Widow       female  1964
# Vision              male  1968

# %% [markdown]
# ## Selección, segmentación e indexación de DataFrame:

# %% [markdown]
# ### Obtener los primeros 5 elementos:

# %%
#marvel_df.iloc[0:5, :]
#marvel_df.iloc[0:5,]
#marvel_df.iloc[:5,]
#marvel_df.head()
marvel_df[0:5]
# Out:
#                 Género   Año
# Nombre
# Spider-Man        male  1962
# Captain America   male  1941
# Wolverine         male  1974
# Iron Man          male  1963
# Thor              male  1963

# %% [markdown]
# ### Obtener los últimos 5 elementos:

# %%
marvel_df.shape[0]
# Out:
# 18

# %%
marvel_df[marvel_df.shape[0]-5:]
# Out:
#                 Género   Año
# Nombre
# Doctor Strange    male  1963
# Scarlet Witch   female  1964
# Wasp            female  1963
# Black Widow     female  1964
# Vision            male  1968

# %%
marvel_df[-5:]
# Out:
#                 Género   Año
# Nombre
# Doctor Strange    male  1963
# Scarlet Witch   female  1964
# Wasp            female  1963
# Black Widow     female  1964
# Vision            male  1968

# %%
marvel_df.iloc[-5:]
# Out:
#                 Género   Año
# Nombre
# Doctor Strange    male  1963
# Scarlet Witch   female  1964
# Wasp            female  1963
# Black Widow     female  1964
# Vision            male  1968

# %%
marvel_df.iloc[-5:,]
# Out:
#                 Género   Año
# Nombre
# Doctor Strange    male  1963
# Scarlet Witch   female  1964
# Wasp            female  1963
# Black Widow     female  1964
# Vision            male  1968

# %% [markdown]
# ### Muestra solo el género de los primeros 5 elementos en marvel_df

# %%
marvel_df.iloc[0:5]['Género']
# Out:
# Nombre
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: Género, dtype: object

# %%
marvel_df.iloc[0:5]['Género'].to_frame()
# Out:
#                 Género
# Nombre
# Spider-Man        male
# Captain America   male
# Wolverine         male
# Iron Man          male
# Thor              male

# %%
#marvel_df.iloc[:5,]['Género'].to_frame()
marvel_df.iloc[:5,].Género.to_frame()
#marvel_df.head().Género.to_frame()
# Out:
#                 Género
# Nombre
# Spider-Man        male
# Captain America   male
# Wolverine         male
# Iron Man          male
# Thor              male

# %% [markdown]
# ### Muestra el atributo 'Año' de todos los elementos intermedios en marvel_df:

# %%
marvel_df[1:-1] # Elementos intermedios
marvel_df.iloc[1:-1]['Año'].to_frame()
# Out:
#                    Año
# Nombre
# Captain America   1941
# Wolverine         1974
# Iron Man          1963
# Thor              1963
# Thing             1961
# Mister Fantastic  1961
# Hulk              1962
# Beast             1963
# Invisible Woman   1961
# Storm             1975
# Hawkeye           1964
# Daredevil         1964
# Doctor Strange    1963
# Scarlet Witch     1964
# Wasp              1963
# Black Widow       1964

# %%
marvel_df.iloc[1:-1].Año.to_frame()
# Out:
#                    Año
# Nombre
# Captain America   1941
# Wolverine         1974
# Iron Man          1963
# Thor              1963
# Thing             1961
# Mister Fantastic  1961
# Hulk              1962
# Beast             1963
# Invisible Woman   1961
# Storm             1975
# Hawkeye           1964
# Daredevil         1964
# Doctor Strange    1963
# Scarlet Witch     1964
# Wasp              1963
# Black Widow       1964

# %% [markdown]
# ### Mostrar el primer y último elemento:

# %%
marvel_df.iloc[[0,-1]]
# Out:
#            Género   Año
# Nombre
# Spider-Man   male  1962
# Vision       male  1968

# %%
marvel_df.iloc[[0,-1]][['Género','Año']]
# Out:
#            Género   Año
# Nombre
# Spider-Man   male  1962
# Vision       male  1964

# %% [markdown]
# ## Manipulación de DataFrame y operaciones:

# %%
marvel_df
# Out:
#                   Género   Año
# Nombre
# Spider-Man          male  1962
# Captain America     male  1941
# Wolverine           male  1974
# Iron Man            male  1963
# Thor                male  1963
# Thing               male  1961
# Mister Fantastic    male  1961
# Hulk                male  1962
# Beast               male  1963
# Invisible Woman   female  1961
# Storm             female  1975
# Hawkeye             male  1964
# Daredevil           male  1964
# Doctor Strange      male  1963
# Scarlet Witch     female  1964
# Wasp              female  1963
# Black Widow       female  1964
# Vision              male  1968

# %% [markdown]
# ### Modificar el atributo Año de 'Visión' al año 1964:

# %%
marvel_df.loc['Vision','Año']
# Out:
# 1968

# %%
marvel_df.loc['Vision','Año']=1964
marvel_df.loc['Vision','Año']
# Out:
# 1964

# %%
marvel_df
# Out:
#                   Género   Año
# Nombre
# Spider-Man          male  1962
# Captain America     male  1941
# Wolverine           male  1974
# Iron Man            male  1963
# Thor                male  1963
# Thing               male  1961
# Mister Fantastic    male  1961
# Hulk                male  1962
# Beast               male  1963
# Invisible Woman   female  1961
# Storm             female  1975
# Hawkeye             male  1964
# Daredevil           male  1964
# Doctor Strange      male  1963
# Scarlet Witch     female  1964
# Wasp              female  1963
# Black Widow       female  1964
# Vision              male  1968

# %% [markdown]
# ### Agregue una nueva columna a marvel_df llamada 'Años_desde' con los años de columna 'Año':

# %%
marvel_df['Año']
# Out:
# Nombre
# Spider-Man          1962
# Captain America     1941
# Wolverine           1974
# Iron Man            1963
# Thor                1963
# Thing               1961
# Mister Fantastic    1961
# Hulk                1962
# Beast               1963
# Invisible Woman     1961
# Storm               1975
# Hawkeye             1964
# Daredevil           1964
# Doctor Strange      1963
# Scarlet Witch       1964
# Wasp                1963
# Black Widow         1964
# Vision              1964
# Name: Año, dtype: int64

# %%
marvel_df['Años_desde'] = 2021 - marvel_df['Año']

# %%
marvel_df
# Out:
#                   Género   Año  Años_desde
# Nombre
# Spider-Man          male  1962          59
# Captain America     male  1941          80
# Wolverine           male  1974          47
# Iron Man            male  1963          58
# Thor                male  1963          58
# Thing               male  1961          60
# Mister Fantastic    male  1961          60
# Hulk                male  1962          59
# Beast               male  1963          58
# Invisible Woman   female  1961          60
# Storm             female  1975          46
# Hawkeye             male  1964          57
# Daredevil           male  1964          57
# Doctor Strange      male  1963          58
# Scarlet Witch     female  1964          57
# Wasp              female  1963          58
# Black Widow       female  1964          57
# Vision              male  1964          57

# %% [markdown]
# ## Arreglos booleanos (Mask):

# %% [markdown]
# ### Dado el DataFrame de marvel_df pandas, haz una máscara que muestre los personajes femeninos:

# %%
marvel_df[marvel_df['Género'] == 'female']
# Out:
#                  Género   Año  Años_desde
# Nombre
# Invisible Woman  female  1961          60
# Storm            female  1975          46
# Scarlet Witch    female  1964          57
# Wasp             female  1963          58
# Black Widow      female  1964          57

# %%
mask = marvel_df['Género'] == 'female'
marvel_df[mask]
# Out:
#                  Género   Año  Años_desde
# Nombre
# Invisible Woman  female  1961          60
# Storm            female  1975          46
# Scarlet Witch    female  1964          57
# Wasp             female  1963          58
# Black Widow      female  1964          57

# %% [markdown]
# ### Dado el DataFrame de marvel df pandas, obtenga los personajes con creados después de 1970:

# %%
marvel_df[marvel_df['Año'] > 1970]
# Out:
#            Género   Año  Años_desde
# Nombre
# Wolverine    male  1974          47
# Storm      female  1975          46

# %% [markdown]
# ### Dado el DataFrame de marvel df pandas, obtenga los personajes femeninos creados después de 1970:

# %%
mask = (marvel_df['Género'] == 'female') & (marvel_df['Año'] > 1970)
marvel_df[mask]
# Out:
#         Género   Año  Años_desde
# Nombre
# Storm   female  1975          46

# %% [markdown]
# ## Resumen de estadísticas:

# %%
marvel_df.describe()
# Out:
#                Año  Años_desde
# count    18.000000   18.000000
# mean   1962.888889   58.111111
# std       6.720372    6.720372
# min    1941.000000   46.000000
# 25%    1962.000000   57.000000
# 50%    1963.000000   58.000000
# 75%    1964.000000   59.000000
# max    1975.000000   80.000000

# %%
#Promedio de los años:
marvel_df['Año'].mean()
# Out:
# 1962.888888888889

# %%
#otra forma
marvel_df.Año.mean()
# Out:
# 1962.888888888889

# %%
# Mostrar el mínimo valor de 'Año'
marvel_df['Año'].min()
# Out:
# 1941

# %%
marvel_df.Año.min()
# Out:
# 1941

# %%
# EL personaj más antiguo
mask = marvel_df['Año'] == marvel_df.Año.min()
marvel_df[mask]
# Out:
#                 Género   Año  Años_desde
# Nombre
# Captain America   male  1941          80

# %% [markdown]
# ## Gráficos básicos de DataFrame:

# %% [markdown]
# ### Restablecer los índices:

# %%
marvel_df
# Out:
#                   Género   Año  Años_desde
# Nombre
# Spider-Man          male  1962          59
# Captain America     male  1941          80
# Wolverine           male  1974          47
# Iron Man            male  1963          58
# Thor                male  1963          58
# Thing               male  1961          60
# Mister Fantastic    male  1961          60
# Hulk                male  1962          59
# Beast               male  1963          58
# Invisible Woman   female  1961          60
# Storm             female  1975          46
# Hawkeye             male  1964          57
# Daredevil           male  1964          57
# Doctor Strange      male  1963          58
# Scarlet Witch     female  1964          57
# Wasp              female  1963          58
# Black Widow       female  1964          57
# Vision              male  1964          57

# %%
marvel_df = marvel_df.reset_index()
marvel_df
# Out:
#               Nombre  Género   Año  Años_desde
# 0         Spider-Man    male  1962          59
# 1    Captain America    male  1941          80
# 2          Wolverine    male  1974          47
# 3           Iron Man    male  1963          58
# 4               Thor    male  1963          58
# 5              Thing    male  1961          60
# 6   Mister Fantastic    male  1961          60
# 7               Hulk    male  1962          59
# 8              Beast    male  1963          58
# 9    Invisible Woman  female  1961          60
# 10             Storm  female  1975          46
# 11           Hawkeye    male  1964          57
# 12         Daredevil    male  1964          57
# 13    Doctor Strange    male  1963          58
# 14     Scarlet Witch  female  1964          57
# 15              Wasp  female  1963          58
# 16       Black Widow  female  1964          57
# 17            Vision    male  1964          57

# %% [markdown]
# ### Graficar los valores de 'Año'

# %%
marvel_df.Año.plot()

# %%
plt.hist(marvel_df.Año)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  3., 12.,  0.,  0.,  2.]),
#  array([1941. , 1944.4, 1947.8, 1951.2, 1954.6, 1958. , 1961.4, 1964.8,
#         1968.2, 1971.6, 1975. ]),
#  <a list of 10 Patch objects>)
